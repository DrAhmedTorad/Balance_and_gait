# %% [markdown]
# # Predection of Mood (Fatigue and fatigue) by different Balance parameters

# %% [markdown]
# # Import necessary libraries

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %% [markdown]
# # Import Data from Excel File

# %%
# Path of Raw Data on the computer
DATA_PATH = r'C:\Users\ahmed\Documents\GitHub\Balance_and_gait\Data\Original_Data_after_Imput_Winser_scaled.xlsx'
# import DATA after having the LABLE (Frist Columen is Y) columnes 2 and 3 are the neuomerical data of predectors form thim Y calculated)
df = pd.read_excel(DATA_PATH)

# %% [markdown]
# # Defining X and y

# %%
#----------------------------------------------------
# y variable definition
#----------------------------------------------------
y1 ='Cate_Med_Fatigue'
y2 ='Cate_Med_Vigor'
y3 ='Cate_M_Fatigue_vigor'
y4 ='CurrentPOMSFatigue'
y5 ='CurrentPOMSVigor'
y_name_list = [y1, y2, y3, y4, y5] 
df=df.astype({y1:'int', y2:'int', y3:'int', y4:'int', y5:'int'}) 
for y in y_name_list:
    df = df.astype({y:'int'})
#----------------------------------------------------
# X variable definition
#----------------------------------------------------
X = df.drop(['CurrentPOMSFatigue', 'Cate_Med_Fatigue', 'CurrentPOMSVigor', 
'Cate_Med_Vigor', 'Cate_M_Fatigue_vigor'], axis=1)
X_columns_names = df.columns.drop(['CurrentPOMSFatigue', 'Cate_Med_Fatigue', 'CurrentPOMSVigor', 
'Cate_Med_Vigor', 'Cate_M_Fatigue_vigor'])

# %% [markdown]
# # Data Recursive feature elimination and cross-validation

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
X, y = make_friedman1(n_samples=50, n_features=10, random_state=0)
estimator = SVR(kernel="linear")
selector = RFE(estimator, step=1)
selector = selector.fit(X, y)
z=selector.n_features_in_
z
# Out:
# 10

# %%
df
# Out:
#      CurrentPOMSFatigue  Cate_Med_Fatigue  CurrentPOMSVigor  Cate_Med_Vigor  \
# 0                     0                 1                13               2
# 1                    13                 2                13               2
# 2                     3                 2                 0               1
# 3                     3                 2                 2               1
# 4                     1                 1                 0               1
# ..                  ...               ...               ...             ...
# 129                   3                 2                 7               1
# 130                  13                 2                11               2
# 131                   5                 1                 1               1
# 132                  10                 1                 6               1
# 133                   2                 1                 1               1
#
#      Cate_M_Fatigue_vigor  Gender1male2female       Age  Heightcm  WeightinKG  \
# 0                       2                 2.0  0.107125  0.897922    0.255639
# 1                       1                 1.0  0.098480  0.862984    0.362587
# 2                       3                 2.0  0.099592  0.822133    0.414213
# 3                       3                 2.0  0.101405  0.862859    0.361833
# 4                       4                 1.0  0.104620  0.873128    0.338769
# ..                    ...                 ...       ...       ...         ...
# 129                     3                 2.0  0.112199  0.793001    0.487377
# 130                     1                 1.0  0.102518  0.863419    0.277633
# 131                     4                 2.0  0.199199  0.855320    0.353556
# 132                     2                 2.0  0.124568  0.855479    0.369202
# 133                     2                 1.0  0.128702  0.860519    0.366099
#
#      CalculatedBMI  ...  PosturalSwayAccRangeCoronalms2_C  \
# 0         0.090765  ...                          0.001066
# 1         0.117786  ...                          0.001975
# 2         0.151626  ...                          0.001683
# 3         0.124663  ...                          0.001192
# 4         0.110048  ...                          0.001126
# ..             ...  ...                               ...
# 129       0.158467  ...                          0.001868
# 130       0.108185  ...                          0.003022
# 131       0.108472  ...                          0.001537
# 132       0.123853  ...                          0.002008
# 133       0.120986  ...                          0.000960
#
#      PosturalSwayAccRangeSagittalms2_C  \
# 0                             0.001489
# 1                             0.002122
# 2                             0.003969
# 3                             0.002525
# 4                             0.001828
# ..                                 ...
# 129                           0.002224
# 130                           0.005169
# 131                           0.002267
# 132                           0.002217
# 133                           0.002341
#
#      PosturalSwayAnglesSwayAreaRadiusCoronaldegrees_C  \
# 0                                            0.003155
# 1                                            0.003875
# 2                                            0.003999
# 3                                            0.003362
# 4                                            0.002964
# ..                                                ...
# 129                                          0.004542
# 130                                          0.006496
# 131                                          0.003548
# 132                                          0.005147
# 133                                          0.002228
#
#      PosturalSwayAngles95EllipseAxis2Radiusdegrees_C  \
# 0                                           0.004333
# 1                                           0.005412
# 2                                           0.010263
# 3                                           0.006830
# 4                                           0.005370
# ..                                               ...
# 129                                         0.006776
# 130                                         0.011978
# 131                                         0.005895
# 132                                         0.005705
# 133                                         0.005212
#
#      PosturalSwayAnglesSwayAreaRotationdegrees_C  \
# 0                                       0.008709
# 1                                       0.005648
# 2                                       0.008550
# 3                                       0.008031
# 4                                       0.008255
# ..                                           ...
# 129                                     0.006161
# 130                                     0.008644
# 131                                     0.007029
# 132                                     0.009572
# 133                                     0.007524
#
#      PosturalSwayAnglesSwayAreadegrees2_C  PosturalSwayAnglesDurations_C  \
# 0                                0.008021                       0.160634
# 1                                0.013387                       0.147671
# 2                                0.025879                       0.149338
# 3                                0.014218                       0.152057
# 4                                0.010033                       0.149457
# ..                                    ...                            ...
# 129                              0.019808                       0.146297
# 130                              0.049508                       0.161817
# 131                              0.013857                       0.142237
# 132                              0.018506                       0.149432
# 133                              0.007372                       0.148452
#
#      PosturalSwayAnglesRMSSwaydegrees_C  \
# 0                              0.002190
# 1                              0.002720
# 2                              0.004499
# 3                              0.003109
# 4                              0.002505
# ..                                  ...
# 129                            0.003331
# 130                            0.005824
# 131                            0.002811
# 132                            0.003138
# 133                            0.002316
#
#      PosturalSwayAnglesRMSSwayCoronaldegrees_C  \
# 0                                     0.001291
# 1                                     0.001706
# 2                                     0.001727
# 3                                     0.001373
# 4                                     0.001221
# ..                                         ...
# 129                                   0.001957
# 130                                   0.002914
# 131                                   0.001460
# 132                                   0.002131
# 133                                   0.000915
#
#      PosturalSwayAnglesRMSSwaySagittaldegrees_C
# 0                                      0.001769
# 1                                      0.002118
# 2                                      0.004153
# 3                                      0.002789
# 4                                      0.002188
# ..                                          ...
# 129                                    0.002696
# 130                                    0.004891
# 131                                    0.002402
# 132                                    0.002304
# 133                                    0.002128
#
# [134 rows x 142 columns]
